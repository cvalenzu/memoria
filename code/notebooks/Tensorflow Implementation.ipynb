# %%
import sys
sys.path.append('../libs')

from esnlib import *
import pandas as pd

import tensorflow as tf

from sklearn import preprocessing
import sklearn.metrics as metrics

import sklearn.model_selection as ms
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class tfESN():
    def __init__(self, n_reservoir = 1000, spectral_radius = 0.135, sparsity=0,
                 leaking_rate=0.3, regularization=1, random_state = None, activation = tf.tanh, initializer = tf.random_uniform):
        self.n_inputs = None
        self.n_outputs = None
        self.n_reservoir = n_reservoir
        self.spectral_radius = tf.convert_to_tensor(spectral_radius,dtype=tf.float64 )
        self.sparsity = tf.convert_to_tensor(sparsity,dtype=tf.float64)
        self.leaking_rate = tf.convert_to_tensor(leaking_rate,dtype=tf.float64)
        self.regularization = tf.convert_to_tensor(regularization,dtype=tf.float64)
        self.last_state = None
        self.activation = activation
        self.random_state = random_state
        self.initializer = initializer
#     def get_params(self,deep=True):
#         params =  {'n_reservoir':self.n_reservoir,'spectral_radius':self.spectral_radius,  'sparsity':self.sparsity,
#                   'leaking_rate': self.leaking_rate, "regularization":self.regularization, "activation": self.activation}
#         if self.n_inputs and self.n_outputs:
#             params["n_inputs"] = self.n_inputs
#             params["n_outputs"] = self.n_outputs
#         if self.random_state:
#             params["random_state"] = self.random_state
#         return params

    def fit(self,X,y):

        in_rows,self.n_inputs = X.get_shape().as_list()
        if len(y.get_shape().as_list()) > 1:
            out_rows, self.n_outputs = y.get_shape().as_list()
        else:
            out_rows = len(y)
            self.n_outputs = 1
        initLen = int(0.01*in_rows)

        #Raise exception
        assert(in_rows == out_rows)

        #Input length
        N = in_rows
        
        #Creating input weights
        self.Win =self.initializer([self.n_reservoir,1+self.n_inputs], seed=self.random_state, minval=-1,maxval=1, name="Win",dtype=tf.float64) 

        #Creating Reservoir weights
        self.W = self.initializer([self.n_reservoir,self.n_reservoir], seed=self.random_state, minval=-1,maxval=1, name="Win",dtype=tf.float64) 
        #Sparsity
        mask =  self.initializer([self.n_reservoir,self.n_reservoir], seed=self.random_state, minval=0,maxval=1,dtype=tf.float64) 
        self.W = tf.boolean_mask(self.W,mask > self.sparsity)
        #Spectral radius
        self.W = tf.multiply(self.W, self.spectral_radius)

#         #Creating state matrix
#         X_states = np.zeros((1+self.n_inputs+self.n_reservoir,N-initLen))

        #Last state
        self.last_state  = tf.zeros(self.n_reservoir,tf.float64)

        #Collecting states
        for t in range(N):
            u = tf.gather(X,t)
            #Calculating new state
#             print(tf.multiply(self.W,self.last_state))
            print(tf.multiply( self.Win, tf.concat([[1],u],0)))
#             self.last_state = tf.multiply(self.last_state,1-self.leaking_rate)\
#                             + tf.multiply(self.leaking_rate, \
#                                           self.activation( tf.multiply( self.Win, tf.concat([[1],u],0)) \
#                                                                     + tf.multiply( self.W, self.last_state  ) ) )
#             if t >= initLen:
#                 X_states[:,t-initLen] = np.hstack((1,u,self.last_state ))


#         Y_T = y[initLen:].T

#         X_sqrd = np.dot(X_states,X_states.T)+  self.regularization*np.eye(1+self.n_inputs+self.n_reservoir)
#         Y_sqrd = np.dot(Y_T,X_states.T)

#         #Getting the output weights using least squares
#         self.Wout=np.dot(Y_sqrd, np.linalg.inv(X_sqrd))

#         return self

#     def predict(self,X, cont=False):
#         Y = np.empty((len(X),self.n_outputs))
#         if not cont:
#             last_state = np.zeros_like(self.last_state)
#         else:
#             last_state = self.last_state
#         for t,u in enumerate(X):
#                 last_state = (1 - self.leaking_rate) * last_state + self.leaking_rate*self.activation( np.dot( self.Win, np.hstack((1,u)))+ \
#                                                                      + np.dot( self.W, last_state  ) )
#                 y = np.dot(self.Wout, np.hstack((1,u,last_state)))
#                 Y[t,:] = y

#         if cont:
#             self.last_state = last_state
#         return Y

# %%
data = pd.Series.from_csv('../../data/meteo.csv')#[:1000]

prediction_steps = 1
input_steps = 12
train_perc = 0.8

X,y = getDataWindowed(data,input_steps,prediction_steps)

trainlen = int(train_perc*len(X))
X_train,X_test = X[:trainlen], X[trainlen:]
y_train,y_test = y[:trainlen], y[trainlen:]

# %%
data.shape

# %%
sess=tf.InteractiveSession()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    esn = tfESN()
    X_train = tf.convert_to_tensor(X_train,dtype=tf.float64)
    X_test = tf.convert_to_tensor(X_test,dtype=tf.float64)
    y_train = tf.convert_to_tensor(y_train,dtype=tf.float64)
    y_test = tf.convert_to_tensor(y_test,dtype=tf.float64)
    esn.fit(X_train,y_train)
# Out:
# Tensor("Mul_809:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_810:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_811:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_812:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_813:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_814:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_815:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_816:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_817:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_818:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_819:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_820:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_821:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_822:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_823:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_824:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_825:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_826:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_827:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_828:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_829:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_830:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_831:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_832:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_833:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_834:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_835:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_836:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_837:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_838:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_839:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_840:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_841:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_842:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_843:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_844:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_845:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_846:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_847:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_848:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_849:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_850:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_851:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_852:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_853:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_854:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_855:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_856:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_857:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_858:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_859:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_860:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_861:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_862:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_863:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_864:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_865:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_866:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_867:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_868:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_869:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_870:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_871:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_872:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_873:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_874:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_875:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_876:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_877:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_878:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_879:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_880:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_881:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_882:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_883:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_884:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_885:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_886:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_887:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_888:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_889:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_890:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_891:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_892:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_893:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_894:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_895:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_896:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_897:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_898:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_899:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_900:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_901:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_902:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_903:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_904:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_905:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_906:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_907:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_908:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_909:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_910:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_911:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_912:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_913:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_914:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_915:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_916:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_917:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_918:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_919:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_920:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_921:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_922:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_923:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_924:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_925:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_926:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_927:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_928:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_929:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_930:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_931:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_932:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_933:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_934:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_935:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_936:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_937:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_938:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_939:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_940:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_941:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_942:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_943:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_944:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_945:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_946:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_947:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_948:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_949:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_950:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_951:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_952:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_953:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_954:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_955:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_956:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_957:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_958:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_959:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_960:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_961:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_962:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_963:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_964:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_965:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_966:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_967:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_968:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_969:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_970:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_971:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_972:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_973:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_974:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_975:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_976:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_977:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_978:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_979:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_980:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_981:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_982:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_983:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_984:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_985:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_986:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_987:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_988:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_989:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_990:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_991:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_992:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_993:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_994:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_995:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_996:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_997:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_998:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_999:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1000:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1001:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1002:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1003:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1004:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1005:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1006:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1007:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1008:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1009:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1010:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1011:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1012:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1013:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1014:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1015:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1016:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1017:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1018:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1019:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1020:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1021:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1022:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1023:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1024:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1025:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1026:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1027:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1028:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1029:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1030:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1031:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1032:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1033:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1034:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1035:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1036:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1037:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1038:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1039:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1040:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1041:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1042:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1043:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1044:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1045:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1046:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1047:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1048:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1049:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1050:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1051:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1052:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1053:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1054:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1055:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1056:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1057:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1058:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1059:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1060:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1061:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1062:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1063:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1064:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1065:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1066:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1067:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1068:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1069:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1070:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1071:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1072:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1073:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1074:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1075:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1076:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1077:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1078:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1079:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1080:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1081:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1082:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1083:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1084:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1085:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1086:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1087:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1088:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1089:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1090:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1091:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1092:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1093:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1094:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1095:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1096:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1097:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1098:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1099:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1100:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1101:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1102:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1103:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1104:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1105:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1106:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1107:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1108:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1109:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1110:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1111:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1112:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1113:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1114:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1115:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1116:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1117:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1118:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1119:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1120:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1121:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1122:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1123:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1124:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1125:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1126:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1127:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1128:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1129:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1130:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1131:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1132:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1133:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1134:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1135:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1136:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1137:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1138:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1139:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1140:0", shape=(1000, 13), dtype=float64)
# Tensor("Mul_1141:0", shape=(1000, 13), dtype=float64)

# %%
# ?tf.concat
